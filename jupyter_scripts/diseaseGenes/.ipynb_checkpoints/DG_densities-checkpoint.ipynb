# %%
import pandas as pd
import numpy as np
import copy

# %%
tanscripts_read = "/home/andre/Documents/trabalho/datasets/Disease_genes/mane/Homo_sapiens.GRCh38.112.chr.gff3"
tanscripts_df = pd.read_csv(tanscripts_read, sep="\t", header=None)
#tanscripts_df

# %%
tanscripts_df = tanscripts_df.rename(columns={0: 'Chr', 1: 'Genome', 2: 'Type', 3: 'First_index', 4: 'Last_index', 5: 'Value', 6: 'Signal', 7: 'Unknown', 8: 'Identifiers'})
tanscripts_df
# Out:
#         Chr  Genome               Type  First_index   Last_index    Value  \
# 0         1  GRCh38         chromosome          1.0  248956422.0        .
# 1         1       .  biological_region      10469.0      11240.0  1.3e+03
# 2         1       .  biological_region      10650.0      10657.0    0.999
# 3         1       .  biological_region      10655.0      10657.0    0.999
# 4         1       .  biological_region      10678.0      10687.0    0.999
# ...      ..     ...                ...          ...          ...      ...
# 3516515   Y       .  biological_region   57215804.0   57215813.0    0.999
# 3516516   Y       .  biological_region   57215832.0   57215840.0    0.999
# 3516517   Y       .  biological_region   57215833.0   57215842.0    0.999
# 3516518   Y       .  biological_region   57215862.0   57215867.0    0.999
# 3516519   Y       .  biological_region   57215862.0   57215870.0    0.999
#
#         Signal Unknown                                        Identifiers
# 0            .       .  ID=chromosome:1;Alias=CM000663.2,chr1,NC_00000...
# 1            .       .           external_name=oe %3D 0.79;logic_name=cpg
# 2            +       .                                 logic_name=eponine
# 3            -       .                                 logic_name=eponine
# 4            +       .                                 logic_name=eponine
# ...        ...     ...                                                ...
# 3516515      -       .                                 logic_name=eponine
# 3516516      +       .                                 logic_name=eponine
# 3516517      -       .                                 logic_name=eponine
# 3516518      +       .                                 logic_name=eponine
# 3516519      -       .                                 logic_name=eponine
#
# [3516520 rows x 9 columns]

# %%
tanscripts_df['Type'].unique()
# Out:
# array(['chromosome', 'biological_region', 'ncRNA_gene', 'lnc_RNA', 'exon',
#        nan, 'pseudogene', 'pseudogenic_transcript', 'miRNA', 'gene',
#        'mRNA', 'five_prime_UTR', 'CDS', 'three_prime_UTR', 'snRNA',
#        'transcript', 'unconfirmed_transcript', 'snoRNA', 'scRNA', 'rRNA',
#        'processed_transcript', 'V_gene_segment', 'D_gene_segment',
#        'J_gene_segment', 'C_gene_segment', 'tRNA'], dtype=object)

# %%
tanscripts_df["Identifiers"][0]
# Out:
# 'ID=chromosome:1;Alias=CM000663.2,chr1,NC_000001.11'

# %%
#chromosmes = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
#genes = tanscripts_df.loc[tanscripts_df['Type'] == "gene"]
#CDSs = tanscripts_df.loc[tanscripts_df['Type'] == "CDS"]
#UTR3 = tanscripts_df.loc[tanscripts_df['Type'] == "three_prime_UTR"]
#UTR5 = tanscripts_df.loc[tanscripts_df['Type'] == "five_prime_UTR"]
#exons = tanscripts_df.loc[tanscripts_df['Type'] == "exon"]

# %%
#UTR5_overlap = UTR5.loc[UTR5["Identifiers"] == UTR5["Identifiers"][3516301]]

# %%
def transcripts_dict_toDF(dictionary):
    transcripts_matrix = []
    concat_list = []
    for value in dictionary.values():
        concat_list.append(value[0])
    return pd.concat(concat_list)

# %%
def transcripts_NoOverlaps(element_type = "CDS"):
    element_df = tanscripts_df.loc[tanscripts_df['Type'] == element_type]
    elements_dict = {}
    #elements_dict.update({"header": element_df.columns.tolist()})
    count = 0
    for row in element_df.index:
        identifiers = element_df["Identifiers"][row]
        transcript_id = identifiers.split(";")[0]
        transcript_length = element_df["Last_index"][row] - element_df["First_index"][row]
        if transcript_id not in elements_dict.keys():
        #if elements_dict.get(transcript_id) == None:
            #elements_dict.update({transcript_id: (element_df.values[row], transcript_length)})
            elements_dict.update({transcript_id: (element_df.iloc[[count]], transcript_length)})
        else:
            #print("resolving overlap...")
            if transcript_length > elements_dict[transcript_id][1]:
                #elements_dict.update({transcript_id: (element_df.values[row], transcript_length)})
                elements_dict.update({transcript_id: (element_df.iloc[[count]], transcript_length)})
        count+=1
    return transcripts_dict_toDF(elements_dict)
    #transcripts_matrix = []
    #for value in elements_dict.values():
    #    transcripts_matrix.append(value[0])
    #return elements_dict
    #return pd.DataFrame(elements_dict.values())
    #return pd.DataFrame(transcripts_matrix)

# %%
#fivePrime_UTR_dict = transcripts_NoOverlaps("five_prime_UTR")

# %%
#for value in fivePrime_UTR_dict.values():
#    print(type(value[0]))
#    break

# %%
#UTR5_noOverlaps_df = transcripts_dict_toDF(fivePrime_UTR_dict)

# %%
#UTR5_noOverlaps_df

# %%
#UTR5_noOverlaps_df["Identifiers"][0]

# %%
def element_matrix(chromosomes_df, sequence_df):
    """
    The matrix representing all intances of a sequence type available from the original transcripts dataframe
    sequence_df = Genes, CDSs, 5 or 3 prime UTR, Exons
    """
    Chromosomes_matrix = []
    for line in chromosomes_df.index:
        chromosome = chromosomes_df["Chr"][line]
        #print("searching citobands in chromossome: ", chromosome)
        chr_size = int(chromosomes_df["Last_index"][line])
        chr_sequence = sequence_df.loc[sequence_df['Chr'] == chromosome]
        chr_array = np.zeros((chr_size), dtype=int)
        #elements region
        for row in chr_sequence.index:
            chr_array[int(chr_sequence["First_index"][row]) : int(chr_sequence["Last_index"][row])] += 1
                
        
        Chromosomes_matrix.append(chr_array)
    return Chromosomes_matrix

# %%
def calc_elementDensity(cytobands_df, region_matrix, col_name="Element_density"):
    #cytobands_df = cytobands_df.drop(cytobands_df[cytobands_df['Chromossome'] == 'chrM'].index)
    densities = []
    for chrom in range(len(cytobands_df["Chromossome"].unique())):             
        chr_cytobands = cytobands_df.loc[cytobands_df['Chromossome'] == cytobands_df["Chromossome"].unique()[chrom]]
        #Calculo da densidade para cada cytoband
        for row in chr_cytobands.index:
            cytoband_array = region_matrix[chrom][int(chr_cytobands["First_index"][row]):int(chr_cytobands["Last_index"][row])]
            dr_length = np.count_nonzero(cytoband_array)
            cytoband_length = chr_cytobands["Size"][row]
            density = dr_length/cytoband_length
            densities.append(round(density, 10))
        
    cytobands_df.insert(len(cytobands_df.columns), col_name, densities, True)

# %%
def calc_ExonIntronDensity(cytobands_df, region_matrix, exons_matrix, col_name1="exon_density", col_name2="intron_density"):
    #cytobands_df = cytobands_df.drop(cytobands_df[cytobands_df['Chromossome'] == 'chrM'].index)
    intron_densities = []
    exon_densities = []
    for chrom in range(len(cytobands_df["Chromossome"].unique())):
        #print("Calculating densities in chromosome ", cytobands_df["Chromossome"].unique()[chrom], " ...")
        chr_cytobands = cytobands_df.loc[cytobands_df['Chromossome'] == cytobands_df["Chromossome"].unique()[chrom]]
        #Calculo da densidade para cada cytoband
        for row in chr_cytobands.index:
            ############################ Resolver problema, o conjunto dos exons contem todo o conjunto dos CDSs ###############################
            region_cytoband_array = region_matrix[chrom][int(chr_cytobands["First_index"][row]):int(chr_cytobands["Last_index"][row])]
            exon_cytoband_array = exons_matrix[chrom][int(chr_cytobands["First_index"][row]):int(chr_cytobands["Last_index"][row])]
            #print("cytoband: ", chr_cytobands["Citoband"][row])
            #print("array_regiao: ", region_cytoband_array)
            #print("exon_regiao: ", exon_cytoband_array)
            region_indexes = np.where(region_cytoband_array != 0)[0].tolist()
            exon_indexes = np.where(exon_cytoband_array != 0)[0].tolist()
            #print("number of elements of region: ", len(region_indexes))
            #print("number of exons in region: ", len(np.intersect1d(region_indexes, exon_indexes)))
            #print("exons in CDS region: ", np.intersect1d(region_indexes, exon_indexes))
            #print("introns in CDS region: ", np.setdiff1d(region_indexes, exon_indexes))
            exon_length = len(np.intersect1d(region_indexes, exon_indexes))    #indices que estam na região e são exões
            intron_length = len(np.setdiff1d(region_indexes, exon_indexes))      #indices que estam na região mas não são exões
            #for region_element in region_indexes:
            #    if region_element in exon_indexes:
            #        exon_length+=1
            #    elif region_element not in exon_indexes:
            #        intron_length+=1
            cytoband_length = chr_cytobands["Size"][row]
            exon_density = exon_length/cytoband_length
            intron_density = intron_length/cytoband_length
            exon_densities.append(round(exon_density, 10))
            intron_densities.append(round(intron_density, 10))   #max 6
            
        
    cytobands_df.insert(len(cytobands_df.columns), col_name1, exon_densities, True)
    cytobands_df.insert(len(cytobands_df.columns), col_name2, intron_densities, True)

# %%
array1 = [1, 2, 3, 6, 7, 8]
array2 = [2, 3, 4, 7, 8, 9]
print(np.intersect1d(array1, array2))
print(np.setdiff1d(array1, array2))
# Out:
# [2 3 7 8]
# [1 6]

# %%
def writeNewtxt(file_path, df):
    """Writes a pandas dataframe into txt, columns separated by tabs ("\t")
    """
    f = open(file_path, 'w')
    df_cols = ""
    for col in df.columns[:-1]:
        df_cols += col + "\t"
    df_cols += df.columns.values[-1]+ "\n"
    f.write(str(df_cols))
    for row in df.values:
        df_row = ""
        for col in row[:-1]:
            df_row += str(col) + "\t"
        df_row += str(row[-1])+ "\n"
        f.write(df_row)
    f.close

# %% [markdown]
# # Code running

# %%
cytoband_read = "/home/andre/Documents/trabalho/cytobands/cytobandFiltered_processed_str_dr.txt"
cytoband_write = "/home/andre/Documents/trabalho/cytobands/cytobandFiltered_processed_str_dr_dg_MANESelect.txt"

cytobands_df = pd.read_csv(cytoband_read, sep="\t")#, header=None))
#cytobands_df2 = pd.read_csv(cytoband_write, sep="\t")

cytobands_df
# Out:
#     Chromossome  First_index  Last_index Citoband  Unkown      Size  \
# 0          chr1            0     2299999   p36.33    gneg   2299999
# 1          chr1      2300000     5299999   p36.32  gpos25   2999999
# 2          chr1      5300000     7099999   p36.31    gneg   1799999
# 3          chr1      7100000     9099999   p36.23  gpos25   1999999
# 4          chr1      9100000    12499999   p36.22    gneg   3399999
# ..          ...          ...         ...      ...     ...       ...
# 858        chrY     12400000    17099999  q11.221  gpos50   4699999
# 859        chrY     17100000    19599999  q11.222    gneg   2499999
# 860        chrY     19600000    23799999  q11.223  gpos50   4199999
# 861        chrY     23800000    26599999   q11.23    gneg   2799999
# 862        chrY     26600000    57227414      q12    gvar  30627414
#
#      TandemRepeats_dens  STRs_dens  LTRs_dens  DRs_density
# 0              0.087516   0.006384   0.084476     0.326328
# 1              0.084077   0.013902   0.079223     0.281556
# 2              0.056236   0.012909   0.051421     0.275410
# 3              0.049082   0.013229   0.042217     0.404844
# 4              0.055881   0.011072   0.048928     0.404047
# ..                  ...        ...        ...          ...
# 858            0.036956   0.014211   0.029356     0.015158
# 859            0.061662   0.015902   0.052790     0.012965
# 860            0.082234   0.005789   0.078347     0.006441
# 861            0.026278   0.009164   0.020721     0.001822
# 862            0.005530   0.001643   0.004251     0.000594
#
# [863 rows x 10 columns]

# %%
#cytobands_df2

# %% [markdown]
# ## Tirar as linhas com a tag "MANE_Plus_Critical"

# %%
#mask1 = ("MANE_Plus_Critical" in tanscripts_df['Identifiers']) == 1)# & (gvs_chr20_df['ALT'].str.len() == 1)
#tanscripts_df_ManeSelect = tanscripts_df[~tanscripts_df['Identifiers'].str.contains("MANE_Plus_Critical")]
MPC_rows = tanscripts_df['Identifiers'].str.contains("MANE_Plus_Clinical", na=False)
tanscripts_df_ManeSelect = tanscripts_df[~MPC_rows]
#tanscripts_df_ManeSelect

# %% [markdown]
# #### Foram retiradas 64 linhas com a tag "MANE_Plus_Clinical"

# %% [markdown]
# ### Criação de variáveis globais necessárias

# %%
############################ Para o dataset sem filtragem #################################################################
chromosomes = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
exons = tanscripts_df.loc[tanscripts_df['Type'] == "exon"]
exon_matrix = element_matrix(chromosomes, exons)

############################ Para o dataset com filtragem pela tag ########################################################
#chromosomes_ManeSelect = tanscripts_df_ManeSelect.loc[tanscripts_df_ManeSelect['Type'] == "chromosome"]
#exons_ManeSelect = tanscripts_df_ManeSelect.loc[tanscripts_df_ManeSelect['Type'] == "exon"]
#exon_matrix_ManeSelect = element_matrix(chromosomes_ManeSelect, exons_ManeSelect)

# %%
############################ Para o dataset com filtragem de transcritos ###################################################
#exons_noOverlaps_df = transcripts_NoOverlaps("exon")
#exon_matrix_noOvrlp = element_matrix(chromosomes, exons_noOverlaps_df)

# %% [markdown]
# ## Sem filtragem

# %%
def study_transcriptDens(cytobands_df, element_type = "CDS", tanscripts_df = tanscripts_df, chromosomes_df = chromosomes):
    #chromosomes_df = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
    sub_trascripts_df = tanscripts_df.loc[tanscripts_df['Type'] == element_type]
    print("building matriz...")
    transcripts_matrix = element_matrix(chromosomes_df, sub_trascripts_df)
    colname = element_type+"s_density"
    print("doing calculations...")
    calc_elementDensity(cytobands_df, transcripts_matrix, colname)
    writeNewtxt(cytoband_write, cytobands_df)

# %%
def study_Trcpts_IExons(cytobands_df, element_type = "CDS", tanscripts_df = tanscripts_df, chromosomes_df = chromosomes, exon_matrix = exon_matrix):
    #chromosomes_df = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
    sub_trascripts_df = tanscripts_df.loc[tanscripts_df['Type'] == element_type]
    exons = tanscripts_df.loc[tanscripts_df['Type'] == "exon"]
    print("building matriz...")
    transcripts_matrix = element_matrix(chromosomes_df, sub_trascripts_df)
    exon_matrix = element_matrix(chromosomes_df, exons)
    print("doing calculations...")
    colname1 = element_type+"Exon_density"
    colname2 = element_type+"Intron_density"
    calc_ExonIntronDensity(cytobands_df, transcripts_matrix, exon_matrix, colname1, colname2)
    writeNewtxt(cytoband_write, cytobands_df)

# %% [markdown]
# ## Com filtragem

# %%
def study_transcriptDens_noOverlps(cytobands_df, element_type = "CDS", chromosomes_df = chromosomes):
    chromosomes_df = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
    element_noOverlaps_df = transcripts_NoOverlaps(element_type)
    print("building matriz...")
    transcript_matrix = element_matrix(chromosomes_df, element_noOverlaps_df)
    colname = element_type+"s_density"
    print("doing calculations...")
    calc_elementDensity(cytobands_df, transcript_matrix, colname)
    writeNewtxt(cytoband_write, cytobands_df)

# %%
def study_Trcpts_IExons_noOverlps(cytobands_df, element_type = "CDS", chromosomes_df = chromosomes, exon_matrix_noOvrlp = exon_matrix_noOvrlp):
    #chromosomes_df = tanscripts_df.loc[tanscripts_df['Type'] == "chromosome"]
    element_noOverlaps_df = transcripts_NoOverlaps(element_type)
    #exons_dict = transcripts_NoOverlaps("exon")
    #exons_noOverlaps_df = transcripts_dict_toDF(exons_dict)
    print("a fazer a matriz...")
    transcript_matrix = element_matrix(chromosomes_df, element_noOverlaps_df)
    #exon_matrix = element_matrix(chromosmes, exons_noOverlaps_df)
    colname1 = element_type+"Intron_density"
    colname2 = element_type+"Exon_density"
    print("a fazer os calculos...")
    calc_ExonIntronDensity(cytobands_df, transcript_matrix, exon_matrix_noOvrlp, colname1, colname2)
    writeNewtxt(cytoband_write, cytobands_df)

# %% [markdown]
# ## Com Nova filtragem é aplicar as funções sem filtragem no dataframe já filtrado: tanscripts_df_ManeSelect

# %% [markdown]
# ## CDS density study

# %%
#study_transcriptDens(cytobands_df, "CDS")
#study_transcriptDens_noOverlps(cytobands_df, "CDS")
study_transcriptDens(cytobands_df, "CDS", tanscripts_df_ManeSelect, chromosomes_ManeSelect)
# Out:
# building matriz...

# %% [markdown]
# ### CDSs' Exon and Intron densities

# %%
#study_Trcpts_IExons(cytobands_df, "CDS")
#study_Trcpts_IExons_noOverlps(cytobands_df, "CDS")
study_Trcpts_IExons(cytobands_df, "CDS", tanscripts_df_ManeSelect, chromosomes_ManeSelect, exon_matrix_ManeSelect)

# %%
cytobands_df

# %% [markdown]
# ## 5 Prime UTR density studies

# %%
#study_transcriptDens(cytobands_df, "five_prime_UTR")
#study_transcriptDens_noOverlps(cytobands_df, "five_prime_UTR")
study_transcriptDens(cytobands_df, "five_prime_UTR", tanscripts_df_ManeSelect, chromosomes_ManeSelect)

# %% [markdown]
# ### 5 Prime UTR Exon and Intron densities

# %%
#study_Trcpts_IExons(cytobands_df, "five_prime_UTR")
#study_Trcpts_IExons_noOverlps(cytobands_df, "five_prime_UTR")
study_Trcpts_IExons(cytobands_df, "five_prime_UTR", tanscripts_df_ManeSelect, chromosomes_ManeSelect, exon_matrix_ManeSelect)

# %%
cytobands_df

# %% [markdown]
# ## Prime 3 UTR density study

# %%
#study_transcriptDens(cytobands_df, "three_prime_UTR")
#study_transcriptDens_noOverlps(cytobands_df, "three_prime_UTR")
study_transcriptDens(cytobands_df, "three_prime_UTR", tanscripts_df_ManeSelect, chromosomes_ManeSelect)

# %% [markdown]
# ## 3 Prime UTR Exon and Intron densities

# %%
#study_Trcpts_IExons(cytobands_df, "three_prime_UTR")
#study_Trcpts_IExons_noOverlps(cytobands_df, "three_prime_UTR")
study_Trcpts_IExons(cytobands_df, "three_prime_UTR", tanscripts_df_ManeSelect, chromosomes_ManeSelect, exon_matrix_ManeSelect)

# %%
cytobands_df

# %% [markdown]
# ## Exons density study

# %%
#study_transcriptDens(cytobands_df, "exon")
#study_transcriptDens_noOverlps(cytobands_df, "exon")
study_transcriptDens(cytobands_df, "exon", tanscripts_df_ManeSelect, chromosomes_ManeSelect)

# %% [markdown]
# ## Resultados finais no dataset de cytobands

# %%
cytobands_df

# %% [markdown]
# ## Resultados depois de filtrar apenas as região de maior tamanho de cada transcrito

# %%
cytobands_df
# Out:
#     Chromossome  First_index  Last_index Citoband  Unkown      Size  \
# 0          chr1            0     2299999   p36.33    gneg   2299999
# 1          chr1      2300000     5299999   p36.32  gpos25   2999999
# 2          chr1      5300000     7099999   p36.31    gneg   1799999
# 3          chr1      7100000     9099999   p36.23  gpos25   1999999
# 4          chr1      9100000    12499999   p36.22    gneg   3399999
# ..          ...          ...         ...      ...     ...       ...
# 858        chrY     12400000    17099999  q11.221  gpos50   4699999
# 859        chrY     17100000    19599999  q11.222    gneg   2499999
# 860        chrY     19600000    23799999  q11.223  gpos50   4199999
# 861        chrY     23800000    26599999   q11.23    gneg   2799999
# 862        chrY     26600000    57227414      q12    gvar  30627414
#
#      TandemRepeats_dens  STRs_dens  LTRs_dens  DRs_density  CDSs_density  \
# 0              0.087516   0.006384   0.084476     0.326328      0.016467
# 1              0.084077   0.013902   0.079223     0.281556      0.006066
# 2              0.056236   0.012909   0.051421     0.275410      0.010266
# 3              0.049082   0.013229   0.042217     0.404844      0.005996
# 4              0.055881   0.011072   0.048928     0.404047      0.009799
# ..                  ...        ...        ...          ...           ...
# 858            0.036956   0.014211   0.029356     0.015158      0.000917
# 859            0.061662   0.015902   0.052790     0.012965      0.002263
# 860            0.082234   0.005789   0.078347     0.006441      0.001096
# 861            0.026278   0.009164   0.020721     0.001822      0.001369
# 862            0.005530   0.001643   0.004251     0.000594      0.000050
#
#      CDSIntron_density  CDSExon_density  five_prime_UTRs_density  \
# 0             0.013392         0.003076                 0.010664
# 1             0.004490         0.001576                 0.003274
# 2             0.006903         0.003362                 0.005659
# 3             0.004821         0.001175                 0.003569
# 4             0.006866         0.002934                 0.004954
# ..                 ...              ...                      ...
# 858           0.000627         0.000290                 0.000927
# 859           0.002263         0.000000                 0.000346
# 860           0.000802         0.000294                 0.000540
# 861           0.001294         0.000075                 0.000652
# 862           0.000043         0.000007                 0.000005
#
#      five_prime_UTRIntron_density  five_prime_UTRExon_density  \
# 0                        0.005135                    0.005529
# 1                        0.001761                    0.001512
# 2                        0.002073                    0.003586
# 3                        0.002070                    0.001499
# 4                        0.002176                    0.002777
# ..                            ...                         ...
# 858                      0.000344                    0.000583
# 859                      0.000338                    0.000008
# 860                      0.000037                    0.000503
# 861                      0.000345                    0.000308
# 862                      0.000000                    0.000005
#
#      three_prime_UTRs_density  three_prime_UTRIntron_density  \
# 0                    0.026310                       0.025853
# 1                    0.019776                       0.019406
# 2                    0.025848                       0.025715
# 3                    0.015875                       0.015746
# 4                    0.029553                       0.028516
# ..                        ...                            ...
# 858                  0.002534                       0.002459
# 859                  0.000937                       0.000635
# 860                  0.002733                       0.002733
# 861                  0.002016                       0.001749
# 862                  0.000094                       0.000094
#
#      three_prime_UTRExon_density  exons_density
# 0                       0.000456       0.133749
# 1                       0.000370       0.060012
# 2                       0.000133       0.056062
# 3                       0.000129       0.034280
# 4                       0.001037       0.066018
# ..                           ...            ...
# 858                     0.000075       0.009953
# 859                     0.000302       0.033020
# 860                     0.000000       0.021283
# 861                     0.000267       0.022278
# 862                     0.000000       0.000460
#
# [863 rows x 20 columns]

# %% [markdown]
# ## Resultados sem usar filtros, o conjunto dos exões cobre completamente as regiões estudadas

# %%
cytobands_df
# Out:
#     Chromossome  First_index  Last_index Citoband  Unkown      Size  \
# 0          chr1            0     2299999   p36.33    gneg   2299999
# 1          chr1      2300000     5299999   p36.32  gpos25   2999999
# 2          chr1      5300000     7099999   p36.31    gneg   1799999
# 3          chr1      7100000     9099999   p36.23  gpos25   1999999
# 4          chr1      9100000    12499999   p36.22    gneg   3399999
# ..          ...          ...         ...      ...     ...       ...
# 858        chrY     12400000    17099999  q11.221  gpos50   4699999
# 859        chrY     17100000    19599999  q11.222    gneg   2499999
# 860        chrY     19600000    23799999  q11.223  gpos50   4199999
# 861        chrY     23800000    26599999   q11.23    gneg   2799999
# 862        chrY     26600000    57227414      q12    gvar  30627414
#
#      TandemRepeats_dens  STRs_dens  LTRs_dens  DRs_density  CDSs_density  \
# 0              0.087516   0.006384   0.084476     0.326328      0.037748
# 1              0.084077   0.013902   0.079223     0.281556      0.015817
# 2              0.056236   0.012909   0.051421     0.275410      0.024363
# 3              0.049082   0.013229   0.042217     0.404844      0.012765
# 4              0.055881   0.011072   0.048928     0.404047      0.029924
# ..                  ...        ...        ...          ...           ...
# 858            0.036956   0.014211   0.029356     0.015158      0.003879
# 859            0.061662   0.015902   0.052790     0.012965      0.002446
# 860            0.082234   0.005789   0.078347     0.006441      0.004806
# 861            0.026278   0.009164   0.020721     0.001822      0.002666
# 862            0.005530   0.001643   0.004251     0.000594      0.000130
#
#      CDSExon_density  CDSIntron_density  five_prime_UTRs_density  \
# 0           0.037748                0.0                 0.012022
# 1           0.015817                0.0                 0.003561
# 2           0.024363                0.0                 0.006496
# 3           0.012765                0.0                 0.004600
# 4           0.029924                0.0                 0.005499
# ..               ...                ...                      ...
# 858         0.003879                0.0                 0.001027
# 859         0.002446                0.0                 0.000346
# 860         0.004806                0.0                 0.000675
# 861         0.002666                0.0                 0.000838
# 862         0.000130                0.0                 0.000006
#
#      five_prime_UTRExon_density  five_prime_UTRIntron_density  \
# 0                      0.012022                           0.0
# 1                      0.003561                           0.0
# 2                      0.006496                           0.0
# 3                      0.004600                           0.0
# 4                      0.005499                           0.0
# ..                          ...                           ...
# 858                    0.001027                           0.0
# 859                    0.000346                           0.0
# 860                    0.000675                           0.0
# 861                    0.000838                           0.0
# 862                    0.000006                           0.0
#
#      three_prime_UTRs_density  three_prime_UTRExon_density  \
# 0                    0.032887                     0.032887
# 1                    0.022181                     0.022181
# 2                    0.033723                     0.033723
# 3                    0.017843                     0.017843
# 4                    0.035758                     0.035758
# ..                        ...                          ...
# 858                  0.002867                     0.002867
# 859                  0.001032                     0.001032
# 860                  0.003568                     0.003568
# 861                  0.002204                     0.002204
# 862                  0.000104                     0.000104
#
#      three_prime_UTRIntron_density  exons_density
# 0                              0.0       0.170647
# 1                              0.0       0.078555
# 2                              0.0       0.082023
# 3                              0.0       0.047006
# 4                              0.0       0.092777
# ..                             ...            ...
# 858                            0.0       0.015587
# 859                            0.0       0.045282
# 860                            0.0       0.035870
# 861                            0.0       0.033834
# 862                            0.0       0.000574
#
# [863 rows x 20 columns]

# %%
#cytobands_df.values[cytobands_df.index[70]]

# %%
def sumOf_columns(df, colums=["CDSIntron_density", "UTR5Intron_density", "UTR3Intron_density"], newColName = "Introns_density"):
    """
    colums is a list of string
    """
    #cytobands_df = cytobands_df.drop(cytobands_df[cytobands_df['Chromossome'] == 'chrM'].index)
    new_densites = []
    for row in df.index:
        density =0
        for column in colums:
            density += df[column][row]
        new_densites.append(round(density, 3))
        
    df.insert(len(df.columns), newColName, new_densites, True)

# %%
sumOf_columns()

# %%
writeNewtxt(cytoPath_write, cytobands_df2)

# %%
CDSs = tanscripts_df.loc[tanscripts_df['Type'] == "CDS"]

# %%
CDSs["Identifiers"][99]
# Out:
# 'ID=CDS:ENSP00000493376;Parent=transcript:ENST00000641515;protein_id=ENSP00000493376'

# %%
#Anterior resultado com calculo de densidades com falhas, sobreposições devido às somas entre elementos diferentes na mesma matrix
# Out:
#     Chromossome  First_index  Last_index Citoband  Unkown      Size  \
# 0          chr1            0     2299999   p36.33    gneg   2299999
# 1          chr1      2300000     5299999   p36.32  gpos25   2999999
# 2          chr1      5300000     7099999   p36.31    gneg   1799999
# 3          chr1      7100000     9099999   p36.23  gpos25   1999999
# 4          chr1      9100000    12499999   p36.22    gneg   3399999
# ..          ...          ...         ...      ...     ...       ...
# 858        chrY     12400000    17099999  q11.221  gpos50   4699999
# 859        chrY     17100000    19599999  q11.222    gneg   2499999
# 860        chrY     19600000    23799999  q11.223  gpos50   4199999
# 861        chrY     23800000    26599999   q11.23    gneg   2799999
# 862        chrY     26600000    57227414      q12    gvar  30627414
#
#      STR_Density  DR_density  CDSs_density  CDSIntron_density  \
# 0          0.088       0.326         0.038              0.022
# 1          0.084       0.282         0.016              0.011
# 2          0.056       0.275         0.024              0.010
# 3          0.049       0.405         0.013              0.004
# 4          0.056       0.404         0.030              0.010
# ..           ...         ...           ...                ...
# 858        0.037       0.015         0.004              0.001
# 859        0.062       0.013         0.002              0.004
# 860        0.082       0.006         0.005              0.004
# 861        0.026       0.002         0.003              0.002
# 862        0.006       0.001         0.000              0.000
#
#      CDSExon_density  5P_UTR_density  UTR5Intron_density  UTR5Exon_density  \
# 0              0.015           0.033               0.022             0.021
# 1              0.005           0.022               0.010             0.014
# 2              0.008           0.034               0.009             0.020
# 3              0.002           0.018               0.003             0.010
# 4              0.008           0.036               0.010             0.019
# ..               ...             ...                 ...               ...
# 858            0.001           0.003               0.001             0.003
# 859            0.004           0.001               0.004             0.003
# 860            0.002           0.004               0.004             0.002
# 861            0.000           0.002               0.003             0.001
# 862            0.000           0.000               0.000             0.000
#
#      3P_UTR_density  UTR3Intron_density  UTR3Exon_density  Exons_density
# 0             0.012               0.025             0.019          0.171
# 1             0.004               0.013             0.006          0.079
# 2             0.006               0.012             0.010          0.082
# 3             0.005               0.004             0.004          0.047
# 4             0.005               0.014             0.010          0.093
# ..              ...                 ...               ...            ...
# 858           0.001               0.001             0.003          0.016
# 859           0.000               0.004             0.002          0.045
# 860           0.001               0.005             0.002          0.036
# 861           0.001               0.003             0.001          0.034
# 862           0.000               0.000             0.000          0.001
#
# [863 rows x 18 columns]
