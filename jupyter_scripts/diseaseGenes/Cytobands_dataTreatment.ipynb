# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
######################################## calc densities ############################################
def calc_DRDensity(cytobands_df, dr_df):
    densities = []
    for chrom in cytobands_df["Chromossome"].unique():             
        print("searching cytobands in chromossome: ", chrom)
        chr_cytobands = cytobands_df.loc[cytobands_df['Chromossome'] == chrom]
        chr_size = chr_cytobands["Last_index"][len(chr_cytobands["Last_index"])-1]+1
        cytobands_dr = np.zeros((chr_size), dtype=int)
        chr_drs = dr_df.loc[dr_df['#chrom'] == chrom]
        #percorrer o dataset pelas vulnerabilidades no cromossoma e anotar na lista np.zeroes
        for row in chr_drs.index:
            for i in range (chr_drs["start"][row], chr_drs["end"][row]):
                cytobands_dr[i]+=1
        #Calculo da densidade para cada cytoband
        for cytoband in chr_cytobands.index:
            cytoband_array = cytobands_str[int(chr_cytobands["First_index"][cytoband]):int(chr_cytobands["Last_index"][cytoband])+1]
            dr_length = np.count_nonzero(cytoband_array)
            cytoband_length = chr_cytobands["Size"][cytoband]
            density = dr_length/cytoband_length
            densities.append(round(density, 10))
        
    cytobands_df.insert(len(cytobands_df.columns), "DRs_density", densities, True)


def writeNewtxt(file_path, df):
    """Writes a pandas dataframe into txt, columns separated by tabs ("\t")
    """
    f = open(file_path, 'w')
    df_cols = ""
    for col in df.columns[:-1]:
        df_cols += col + "\t"
    df_cols += df.columns.values[-1]+ "\n"
    f.write(str(df_cols))
    for row in df.values:
        df_row = ""
        for col in row[:-1]:
            df_row += str(col) + "\t"
        df_row += str(row[-1])+ "\n"
        f.write(df_row)
    f.close

# %%
cytoband_read = "/home/andre/Documents/trabalho/cytobands/cytobandFiltered_processed_str.txt"
cytoband_write = "/home/andre/Documents/trabalho/cytobands/cytobandFiltered_processed_str_dr.txt"
disease_regions_read = "/home/andre/Documents/trabalho/datasets/Disease_genes/genehancer/GeneHancer_v5.20_processed.gff"

cytobands_df = pd.read_csv(cytoband_read, sep="\t")#, header=None))
dr_df = pd.read_csv(disease_regions_read, sep="\t")

cytobands_df
# Out:
#     Chromossome  First_index  Last_index Citoband  Unkown      Size  \
# 0          chr1            0     2299999   p36.33    gneg   2299999
# 1          chr1      2300000     5299999   p36.32  gpos25   2999999
# 2          chr1      5300000     7099999   p36.31    gneg   1799999
# 3          chr1      7100000     9099999   p36.23  gpos25   1999999
# 4          chr1      9100000    12499999   p36.22    gneg   3399999
# ..          ...          ...         ...      ...     ...       ...
# 858        chrY     12400000    17099999  q11.221  gpos50   4699999
# 859        chrY     17100000    19599999  q11.222    gneg   2499999
# 860        chrY     19600000    23799999  q11.223  gpos50   4199999
# 861        chrY     23800000    26599999   q11.23    gneg   2799999
# 862        chrY     26600000    57227414      q12    gvar  30627414
#
#      TandemRepeats_dens  STRs_dens  LTRs_dens
# 0              0.087516   0.006384   0.084476
# 1              0.084077   0.013902   0.079223
# 2              0.056236   0.012909   0.051421
# 3              0.049082   0.013229   0.042217
# 4              0.055881   0.011072   0.048928
# ..                  ...        ...        ...
# 858            0.036956   0.014211   0.029356
# 859            0.061662   0.015902   0.052790
# 860            0.082234   0.005789   0.078347
# 861            0.026278   0.009164   0.020721
# 862            0.005530   0.001643   0.004251
#
# [863 rows x 9 columns]

# %%
calc_DRDensity(cytobands_df, dr_df)
cytobands_df
# Out:
# searching cytobands in chromossome:  chr1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 calc_DRDensity(cytobands_df, dr_df)
#       2 cytobands_df
#
# Cell In[13], line 16, in calc_DRDensity(cytobands_df, dr_df)
#      14 #Calculo da densidade para cada cytoband
#      15 for cytoband in chr_cytobands.index:
# ---> 16     cytoband_array = cytobands_str[int(chr_cytobands["First_index"][cytoband]):int(chr_cytobands["Last_index"][cytoband])+1]
#      17     dr_length = np.count_nonzero(cytoband_array)
#      18     cytoband_length = chr_cytobands["Size"][cytoband]
#
# NameError: name 'cytobands_str' is not defined

# %%
writeNewtxt(cytoPath_write, cytobands_df)
